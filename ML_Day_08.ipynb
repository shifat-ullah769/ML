# %%
# Working with JSON
import pandas as pd

# %%
df = pd.read_json('/content/2_Recipe_json.json', lines=True)

# %%
df
# Out:
#                                             recipe_title           category  \
# 0             Air Fryer Potato Slices with Dipping Sauce  Air Fryer Recipes
# 1                             Gochujang Pork Belly Bites  Air Fryer Recipes
# 2      3-Ingredient Air Fryer Everything Bagel Chicke...  Air Fryer Recipes
# 3             Air Fryer Everything Bagel Chicken Cutlets  Air Fryer Recipes
# 4                  Air Fryer Honey Sriracha Salmon Bites  Air Fryer Recipes
# ...                                                  ...                ...
# 62121                              Rice Zucchini Muffins    Zucchini Breads
# 62122                       Gluten-Free Zucchini Muffins    Zucchini Breads
# 62123                                 Five Spice Muffins    Zucchini Breads
# 62124            Low-Fat Chocolate Zucchini Mini Muffins    Zucchini Breads
# 62125                       Vegan Zucchini Bread Muffins    Zucchini Breads
#
# ...

# %%
# Working with SQL

# Step-1
  #  - download the dataset and export it to phpmyadmin by creating a database
# Step -2
  # - $pip install mysql.connector
# Step-3
  # - import mysql.connector
# Step -4
  # -Create connection with  mysql phpmyadmin through python
  # conn = mysql.connector.connect(host='localhost', user='root', password='',database='database name where data exported')
# Step -5
  # - Read the dataset
  # - df = pd.read_mysql_query("sql query{SELECT * FROM table_name}", connection_varible name{conn})

# %%
# Fetching data from API
# import requests


# df = pd.DataFrame()  -- created an empty dataframe
# for i in range('length of the json pages/observations'):
#   response = requests.get('enter the url of api datasets')
#   temp_df = pd.DataFrame(response.json()[response.json()['key_name_of_the_particular_dictionary_which_data_we_need']])[['features list that we need only to store in our dataframe']]
#   df = df.append(temp_df, ignore_index=True)
